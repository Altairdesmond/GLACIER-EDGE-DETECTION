# %%
#Prepare for training data
import cv2, matplotlib
import numpy as np
import glob, os
import matplotlib.pyplot as plt

path="D:\\MEGA BACKUP\\PC\\Nielit\\ALASKA GLACIERS\\training"
files= glob.glob(os.path.join(path, '*.jpg'))
files.sort()

#Load the image data (Jpg) 
data=[]
for i,file in  enumerate(files):
    cups = cv2.imread(file)
    #preprocess by blurring and grayscale
    cups_preprocessed  = cv2.cvtColor(cv2.GaussianBlur(cups, (7,7), 0), cv2.COLOR_BGR2GRAY)
    #find binary image with edges
    _, cups_thresh = cv2.threshold(cups_preprocessed, 30, 255, cv2.THRESH_BINARY)
    plt.subplot(1,2,1)
    plt.imshow(cv2.cvtColor(cups_thresh, cv2.COLOR_GRAY2RGB))
    data.append(cups_preprocessed)
files.sort()
files_length = len(files)

#Detection of edge of object in images
# save them as png file
for ii in range(files_length):
    
    cups_edges = cv2.Canny(data[ii], threshold1=30, threshold2=60) #Canny Edge Detection 
    plt.subplot(1,2,2)
    plt.imshow(cv2.cvtColor(cups_edges, cv2.COLOR_GRAY2RGB))
   
    cv2.imwrite(os.path.join(path, 'T0{}.png'.format(ii)),cups_edges )
    cv2.waitKey(0)
#Now we got two kinds of images 
# save them as png file
# Out:
# C:\Users\Rishi\anaconda3\envs\altair\lib\site-packages\ipykernel_launcher.py:19: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# C:\Users\Rishi\anaconda3\envs\altair\lib\site-packages\ipykernel_launcher.py:30: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array

# %%
# loading training data
# I used images of different glaciers (Greenland, Patagonia, Alaska and somehwere in the world)  as training data
import glob
import numpy as np
from tensorflow.keras.preprocessing.image import load_img, img_to_array

files = glob.glob('D:\\MEGA BACKUP\\PC\\Nielit\\ALASKA GLACIERS\\training/*.jpg')

imgs = np.array([img_to_array(load_img(f)) for f in files])

imgs.shape
# Out:
# (200, 200, 200, 3)

# %%
# loading label data
# Classified label data as 1 and 0 using threshold (128)

import os

th = 128

labels = np.array([img_to_array(load_img(f"{os.path.splitext(f)[0]}.png", color_mode = 'grayscale')) for f in files])

labels[labels < th] = 0  #(should be black)

labels[labels >= th] = 1 #(should be white)

labels.shape
# Out:
# (200, 200, 200, 1)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dropout
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2D, Conv2DTranspose
from tensorflow.keras.layers import MaxPool2D
from tensorflow.keras.layers import Conv2D,BatchNormalization,MaxPooling2D,concatenate,Conv2DTranspose,Lambda,Multiply,Add,Dense
#########################
#Build up Autoencoder
#########################

OUTPUT_CHANNELS = 3
IMG_HEIGHT =200
IMG_WIDTH =200

inputs = Input((IMG_HEIGHT, IMG_WIDTH, OUTPUT_CHANNELS))

#input = Input(shape = imgs.shape[1:])

#x = input

#inputs = BatchNormalization()(inputs)

# Encoder

c1 = Conv2D(32, 3, padding='same', activation = 'relu')(inputs) #channel changed (16-32) 
p1 = MaxPool2D()(c1)

p1 = BatchNormalization()(p1)
d1 = Dropout(0.2)(p1)

c2 = Conv2D(64, 3, padding='same', activation = 'relu')(d1) #channel changed (32-64) 
c2 = Conv2D(64, 3, padding='same', activation = 'relu')(c2)
c2 = Conv2D(64, 3, padding='same', activation = 'relu')(c2)
p2 = MaxPool2D()(c2)

p2 = BatchNormalization()(p2)
d2 = Dropout(0.2)(p2)

c3 = Conv2D(128, 3, padding='same', activation = 'relu')(d2)#channel changed (64-128) 
c3 = Conv2D(128, 3, padding='same', activation = 'relu')(c3)
c3 = Conv2D(128, 3, padding='same', activation = 'relu')(c3)
p3 = MaxPool2D()(c3)

p3 = BatchNormalization()(p3)
d3 = Dropout(0.3)(p3)

c4 = Conv2D(256, 3, padding='same', activation = 'relu')(d3)#channel changed (128-256) 
c4 = Conv2D(256, 3, padding='same', activation = 'relu')(c4)

c4 = BatchNormalization()(c4)
d4 = Dropout(0.5)(c4)
##########
#mid = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (p6)
# Decoder

u5 = Conv2DTranspose(128, 3, strides = 2, padding='same', activation = 'relu')(d4)
c5 = concatenate([u5, c3])  #skip connection
c5 = Conv2D(128, 3, padding='same', activation = 'relu')(c5)
c5 = Conv2D(128, 3, padding='same', activation = 'relu')(c5)
c5 = Conv2D(128, 3, padding='same', activation = 'relu')(c5)

c5 = BatchNormalization()(c5)
d5 = Dropout(0.2)(c5)

u6 = Conv2DTranspose(32, 3, strides = 2, padding='same', activation = 'relu')(d5)
c6 = concatenate([u6, c2])#skip connection
c6 = Conv2D(64, 3, padding='same', activation = 'relu')(c6)
c6 = Conv2D(64, 3, padding='same', activation = 'relu')(c6)
c6 = Conv2D(64, 3, padding='same', activation = 'relu')(c6)

c6 = BatchNormalization()(c6)
d6 = Dropout(0.3)(c6)

u7 = Conv2DTranspose(16, 3, strides = 2, padding='same', activation = 'relu')(d6)
c7 = concatenate([u7, c1])#skip connection
c7 = Conv2D(32, 3, padding='same', activation = 'relu')(c7)

c7 = BatchNormalization()(c7)
d7 = Dropout(0.5)(c7)

outputs = Conv2D(1, 1, activation = 'sigmoid')(d7)


#Define the model
model = Model(inputs=[inputs], outputs=[outputs])

model.compile(loss = 'mse', optimizer = 'adam',  metrics=['mae', 'acc'])

model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\Rishi\anaconda3\envs\altair\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 200, 200, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 200, 200, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 100, 100, 32) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 100, 100, 32) 128         max_pooling2d[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 100, 100, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 100, 100, 64) 18496       dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 100, 100, 64) 36928       conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 100, 100, 64) 36928       conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 50, 50, 64)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 50, 50, 64)   256         max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 50, 50, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 50, 50, 128)  73856       dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 50, 50, 128)  147584      conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 50, 50, 128)  147584      conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 25, 25, 128)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 25, 25, 128)  512         max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 25, 25, 128)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 25, 25, 256)  295168      dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 25, 25, 256)  590080      conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 25, 25, 256)  1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 25, 25, 256)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 50, 50, 128)  295040      dropout_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 50, 50, 256)  0           conv2d_transpose[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 50, 50, 128)  295040      concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 50, 50, 128)  147584      conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 50, 50, 128)  147584      conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 50, 50, 128)  512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 50, 50, 128)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 100, 100, 32) 36896       dropout_4[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 100, 100, 96) 0           conv2d_transpose_1[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 100, 100, 64) 55360       concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 100, 100, 64) 36928       conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 100, 100, 64) 36928       conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 100, 100, 64) 256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 100, 100, 64) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 200, 200, 16) 9232        dropout_5[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 200, 200, 48) 0           conv2d_transpose_2[0][0]
#                                                                  conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 200, 200, 32) 13856       concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 200, 200, 32) 128         conv2d_15[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 200, 200, 32) 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 200, 200, 1)  33          dropout_6[0][0]
# ==================================================================================================
# Total params: 2,424,817
# Trainable params: 2,423,409
# Non-trainable params: 1,408
# __________________________________________________________________________________________________

# %%
hist = model.fit(imgs, labels, initial_epoch = 120,epochs =160 , batch_size =10)
# Out:
# Epoch 121/160
# 200/200 [==============================] - 62s 309ms/sample - loss: 0.2285 - mean_absolute_error: 0.4512 - acc: 0.6900
# Epoch 122/160
# 200/200 [==============================] - 63s 317ms/sample - loss: 0.1707 - mean_absolute_error: 0.3721 - acc: 0.8619
# Epoch 123/160
# 200/200 [==============================] - 62s 310ms/sample - loss: 0.1372 - mean_absolute_error: 0.3269 - acc: 0.9095
# Epoch 124/160
# 200/200 [==============================] - 62s 310ms/sample - loss: 0.1135 - mean_absolute_error: 0.2891 - acc: 0.9260
# Epoch 125/160
# 200/200 [==============================] - 62s 310ms/sample - loss: 0.0964 - mean_absolute_error: 0.2619 - acc: 0.9345
# Epoch 126/160
# 200/200 [==============================] - 62s 312ms/sample - loss: 0.0823 - mean_absolute_error: 0.2379 - acc: 0.9415
# Epoch 127/160
# 200/200 [==============================] - 62s 311ms/sample - loss: 0.0715 - mean_absolute_error: 0.2172 - acc: 0.9463
# Epoch 128/160
# 200/200 [==============================] - 62s 310ms/sample - loss: 0.0623 - mean_absolute_error: 0.2003 - acc: 0.9512
# Epoch 129/160
# 200/200 [==============================] - 62s 312ms/sample - loss: 0.0555 - mean_absolute_error: 0.1838 - acc: 0.9537
# Epoch 130/160
# 200/200 [==============================] - 62s 311ms/sample - loss: 0.0498 - mean_absolute_error: 0.1684 - acc: 0.9558
# Epoch 131/160
# 200/200 [==============================] - 62s 310ms/sample - loss: 0.0455 - mean_absolute_error: 0.1561 - acc: 0.9576
# Epoch 132/160
# 200/200 [==============================] - 62s 311ms/sample - loss: 0.0422 - mean_absolute_error: 0.1465 - acc: 0.9590
# Epoch 133/160
# 200/200 [==============================] - 62s 310ms/sample - loss: 0.0397 - mean_absolute_error: 0.1381 - acc: 0.9600
# Epoch 134/160
# 200/200 [==============================] - 62s 311ms/sample - loss: 0.0378 - mean_absolute_error: 0.1330 - acc: 0.9611
# Epoch 135/160
# 200/200 [==============================] - 62s 310ms/sample - loss: 0.0417 - mean_absolute_error: 0.1294 - acc: 0.9570
# Epoch 136/160
# 200/200 [==============================] - 62s 309ms/sample - loss: 0.0406 - mean_absolute_error: 0.1281 - acc: 0.9587
# Epoch 137/160
# 200/200 [==============================] - 62s 309ms/sample - loss: 0.0376 - mean_absolute_error: 0.1191 - acc: 0.9595
# Epoch 138/160
# 200/200 [==============================] - 62s 312ms/sample - loss: 0.0357 - mean_absolute_error: 0.1128 - acc: 0.9605
# Epoch 139/160
# 200/200 [==============================] - 62s 310ms/sample - loss: 0.0345 - mean_absolute_error: 0.1065 - acc: 0.9609
# Epoch 140/160
# 200/200 [==============================] - 62s 309ms/sample - loss: 0.0338 - mean_absolute_error: 0.1022 - acc: 0.9612
# Epoch 141/160
# 200/200 [==============================] - 62s 310ms/sample - loss: 0.0332 - mean_absolute_error: 0.0983 - acc: 0.9615
# Epoch 142/160
# 200/200 [==============================] - 62s 310ms/sample - loss: 0.0327 - mean_absolute_error: 0.0953 - acc: 0.9617
# Epoch 143/160
# 200/200 [==============================] - 62s 310ms/sample - loss: 0.0323 - mean_absolute_error: 0.0927 - acc: 0.9619
# Epoch 144/160
# 200/200 [==============================] - 62s 310ms/sample - loss: 0.0316 - mean_absolute_error: 0.0894 - acc: 0.9622
# Epoch 145/160
# 200/200 [==============================] - 62s 309ms/sample - loss: 0.0311 - mean_absolute_error: 0.0873 - acc: 0.9624
# Epoch 146/160
# 200/200 [==============================] - 62s 309ms/sample - loss: 0.0313 - mean_absolute_error: 0.0856 - acc: 0.9622
# Epoch 147/160
# 200/200 [==============================] - 62s 309ms/sample - loss: 0.0311 - mean_absolute_error: 0.0834 - acc: 0.9623
# Epoch 148/160
# 200/200 [==============================] - 62s 311ms/sample - loss: 0.0304 - mean_absolute_error: 0.0815 - acc: 0.9627
# Epoch 149/160
# 200/200 [==============================] - 62s 309ms/sample - loss: 0.0302 - mean_absolute_error: 0.0802 - acc: 0.9629
# Epoch 150/160
# 200/200 [==============================] - 63s 316ms/sample - loss: 0.0299 - mean_absolute_error: 0.0791 - acc: 0.9631
# Epoch 151/160
# 200/200 [==============================] - 62s 309ms/sample - loss: 0.0299 - mean_absolute_error: 0.0782 - acc: 0.9631
# Epoch 152/160
# 200/200 [==============================] - 62s 309ms/sample - loss: 0.0297 - mean_absolute_error: 0.0768 - acc: 0.9633
# Epoch 153/160
# 200/200 [==============================] - 62s 309ms/sample - loss: 0.0294 - mean_absolute_error: 0.0755 - acc: 0.9635
# Epoch 154/160
# 200/200 [==============================] - 62s 309ms/sample - loss: 0.0292 - mean_absolute_error: 0.0746 - acc: 0.9637
# Epoch 155/160
# 200/200 [==============================] - 62s 309ms/sample - loss: 0.0293 - mean_absolute_error: 0.0739 - acc: 0.9635
# Epoch 156/160
# 200/200 [==============================] - 62s 309ms/sample - loss: 0.0291 - mean_absolute_error: 0.0732 - acc: 0.9636
# Epoch 157/160
# 200/200 [==============================] - 62s 308ms/sample - loss: 0.0289 - mean_absolute_error: 0.0722 - acc: 0.9638
# Epoch 158/160
# 200/200 [==============================] - 62s 309ms/sample - loss: 0.0290 - mean_absolute_error: 0.0716 - acc: 0.9638
# Epoch 159/160
# 200/200 [==============================] - 62s 309ms/sample - loss: 0.0288 - mean_absolute_error: 0.0708 - acc: 0.9640
# Epoch 160/160
# 200/200 [==============================] - 62s 308ms/sample - loss: 0.0287 - mean_absolute_error: 0.0700 - acc: 0.9641

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (8, 4)

plt.subplot(1, 3, 1)
plt.plot(hist.history['loss'])

plt.subplot(1, 3, 2)
plt.plot(hist.history['mean_absolute_error'])

plt.subplot(1, 3, 3)
plt.plot(hist.history['acc'])
plt.tight_layout()

# %%
def predict(index, s = 12.0):
    plt.rcParams['figure.figsize'] = (s, s)

    sh = imgs.shape[1:-1]

    # detection of outline of glaciers
    pred = model.predict(np.array([imgs[index]]))[0]
    pred *= 255

    plt.subplot(1, 3, 1)
    # Show the raw image
    plt.imshow(imgs[index].astype(int))

    plt.subplot(1, 3, 2)
    # show the label image (the edge of objects)
    plt.imshow(labels[index].reshape(sh), cmap = 'gray')

    plt.subplot(1, 3, 3)
    # the result of predictions
    plt.imshow(pred.reshape(sh).astype(int), cmap = 'gray')

predict(10)

# %%
def predict_eval(file, s = 10.0):
    plt.rcParams['figure.figsize'] = (s, s)

    img = img_to_array(load_img(file))

    # Detection of outline of glaciers
    pred = model.predict(np.array([img]))[0]
    pred *= 255
    #pred_data.append(pred)
    
    plt.subplot(1, 2, 1)
    # show the raw image
    plt.imshow(img.astype(int))

    plt.subplot(1, 2, 2)
    # the result of prediction based on the satellite image wihch have never trained in the model
    plt.imshow(pred.reshape(pred.shape[:-1]).astype(int), cmap = 'gray')
    cv2.imwrite("try12_pred.png", pred.reshape(pred.shape[:-1]).astype(int))

# %%
#Save the above model
model.save('D:\\MEGA BACKUP\\PC\\Nielit\\ALASKA GLACIERS\\newmodel_200_chanelchange.h5py')

# %%
import sys
import os
import glob
import numpy as np
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.models import load_model
import cv2
import matplotlib.pyplot as plt

path="prediction/"
files= glob.glob(os.path.join(path, '*.jpg'))
files.sort()
files_length = len(files)


def predict_eval(files, s = 5.0):
    for i in files:
        img = img_to_array(load_img(files))
        plt.rcParams['figure.figsize'] = (s, s)
    # Detection of outline
        pred = model.predict(np.array([img]))[0]
        pred *= 255
    #pred_data.append(pred)
    
        plt.subplot(1, 2, 1)
    # show the raw image
        plt.imshow(img.astype(int))

        plt.subplot(1, 2, 2)
    # the result of prediction based on the satellite image wihch have never trained in the model
        plt.imshow(pred.reshape(pred.shape[:-1]).astype(int), cmap = 'gray')
#for ii in range(files_length):
        cv2.imwrite(os.path.join(path, 'try{}.png'.format(i)),pred.reshape(pred.shape[:-1]).astype(int))
        
    #cv2.imwrite("try13_pred.png", pred.reshape(pred.shape[:-1]).astype(int))

# %%
#Prediction of outline of glaciers in the image
path="D:\\MEGA BACKUP\\PC\\Nielit\\ALASKA GLACIERS\\prediction/"
files= glob.glob(os.path.join(path, '*.jpg'),recursive=True)
files.sort()
for file in files:
    print(file)
    predict_eval(file)
    plt.show()
# Out:
# D:\MEGA BACKUP\PC\Nielit\ALASKA GLACIERS\prediction\try0.jpg
# C:\Users\Rishi\anaconda3\envs\altair\lib\site-packages\ipykernel_launcher.py:25: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# C:\Users\Rishi\anaconda3\envs\altair\lib\site-packages\ipykernel_launcher.py:29: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# D:\MEGA BACKUP\PC\Nielit\ALASKA GLACIERS\prediction\try1.jpg
# D:\MEGA BACKUP\PC\Nielit\ALASKA GLACIERS\prediction\try2.jpg
# D:\MEGA BACKUP\PC\Nielit\ALASKA GLACIERS\prediction\try3.jpg
# D:\MEGA BACKUP\PC\Nielit\ALASKA GLACIERS\prediction\try4.jpg
# D:\MEGA BACKUP\PC\Nielit\ALASKA GLACIERS\prediction\try5.jpg
# D:\MEGA BACKUP\PC\Nielit\ALASKA GLACIERS\prediction\try6.jpg
# D:\MEGA BACKUP\PC\Nielit\ALASKA GLACIERS\prediction\try7.jpg
# D:\MEGA BACKUP\PC\Nielit\ALASKA GLACIERS\prediction\try8.jpg
# D:\MEGA BACKUP\PC\Nielit\ALASKA GLACIERS\prediction\try9.jpg

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
#Overlay the prediction with raw data
plt.figure(figsize=(15,15))

img1 = cv2.imread('D:\\MEGA BACKUP\\PC\\Nielit\\ALASKA GLACIERS\\prediction/try0.jpg')
img2 = cv2.imread('D:\\MEGA BACKUP\\PC\\Nielit\\ALASKA GLACIERS\\prediction/try0.png')
img3 = cv2.imread('D:\\MEGA BACKUP\\PC\\Nielit\\ALASKA GLACIERS\\prediction/try1.jpg')
img4 = cv2.imread('D:\\MEGA BACKUP\\PC\\Nielit\\ALASKA GLACIERS\\prediction/try1.png')
img5 = cv2.imread('D:\\MEGA BACKUP\\PC\\Nielit\\ALASKA GLACIERS\\prediction/try2.jpg')
img6 = cv2.imread('D:\\MEGA BACKUP\\PC\\Nielit\\ALASKA GLACIERS\\prediction/try2.png')
img7 = cv2.imread('D:\\MEGA BACKUP\\PC\\Nielit\\ALASKA GLACIERS\\prediction/try3.jpg')
img8 = cv2.imread('D:\\MEGA BACKUP\\PC\\Nielit\\ALASKA GLACIERS\\prediction/try3.png')


blended = cv2.addWeighted(src1=img1,alpha=0.7,src2=img2,beta=2.0,gamma=50)
blended1 = cv2.addWeighted(src1=img3,alpha=0.7,src2=img4,beta=2.0,gamma=50)
blended2 = cv2.addWeighted(src1=img5,alpha=0.7,src2=img6,beta=2.0,gamma=50)
blended3 = cv2.addWeighted(src1=img7,alpha=0.7,src2=img8,beta=2.0,gamma=50)

plt.subplot(2,4,1)
plt.imshow(blended)
plt.title('1986')
plt.subplot(2,4,2)
plt.imshow(blended1)
plt.title('1996')
plt.subplot(2,4,3)
plt.imshow(blended2)
plt.title('2001')
plt.subplot(2,4,4)
plt.imshow(blended3)
plt.title('2009')

plt.subplot(2,4,5)
plt.imshow(img1)
img0 = img_to_array(load_img('D:\\MEGA BACKUP\\PC\\Nielit\\ALASKA GLACIERS\\prediction/try0.jpg'))
plt.imshow(img0.astype(int))
plt.title('1986')

plt.subplot(2,4,6)
img1 = img_to_array(load_img('D:\\MEGA BACKUP\\PC\\Nielit\\ALASKA GLACIERS\\prediction/try1.jpg'))
plt.imshow(img1.astype(int))
#plt.imshow(img3)
plt.title('1996')

plt.subplot(2,4,7)
plt.title('2001')
img2 = img_to_array(load_img('D:\\MEGA BACKUP\\PC\\Nielit\\ALASKA GLACIERS\\prediction/try2.jpg'))
plt.imshow(img2.astype(int))

plt.subplot(2,4,8)
img3 = img_to_array(load_img('D:\\MEGA BACKUP\\PC\\Nielit\\ALASKA GLACIERS\\prediction/try3.jpg'))
plt.imshow(img3.astype(int))
#plt.imshow(img7)
plt.title('2009')


plt.tight_layout()
plt.show()
